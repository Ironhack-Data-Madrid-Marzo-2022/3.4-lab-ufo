# %% [markdown]
# # UFO Question
#
# Our data science team has predicted that the Earth is going to be invaded by an alien force in the
# next years. Our only hope is to replicate a device that can block all alien technology in a radius of
# ~300km. Sadly, the device was sold in 2004 to an anonymous buyer to protect her hometown and
# we don't know how contact her again. We know that the device has been active since 2004 in one
# city in the USA, and we want to know where to start our search.
# We've included a dataset called ​ufo.csv​. This dataset contains over 80,000 reports of UFO sightings
# over the last century (all of them verified by the ESA). Using this dataset, try to guess the city in
# which the device has been hidden.

# %%
# %pip install pymongo

from pymongo import MongoClient
import pandas as pd
import re
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install folium
import folium

# %%
cliente=MongoClient()

db=cliente.ufo

# %%
df = pd.read_csv (r'ufo.csv')
df.shape
# Out:
# (78509, 14)

# %%
ufo=df.copy()

ufo=ufo[(ufo.country=="us")]


ufo
# Out:
#        Unnamed: 0          datetime        city state country     shape  \
# 0               0  10/10/1949 20:30  san marcos    tx      us  cylinder
# 3               3  10/10/1956 21:00        edna    tx      us    circle
# 4               4  10/10/1960 20:00     kaneohe    hi      us     light
# 5               5  10/10/1961 19:00     bristol    tn      us    sphere
# 7               7  10/10/1965 23:45     norwalk    ct      us      disk
# ...           ...               ...         ...   ...     ...       ...
# 78504       80326    9/9/2013 21:00   woodstock    ga      us    sphere
# 78505       80328    9/9/2013 22:00       boise    id      us    circle
# 78506       80329    9/9/2013 22:00        napa    ca      us     other
# 78507       80330    9/9/2013 22:20      vienna    va      us    circle
# 78508       80331    9/9/2013 23:00      edmond    ok      us     cigar
#
#        duration  total_time  \
# 0        2700.0  45 minutes
# 3          20.0    1/2 hour
# ...

# %%
ufo1=ufo[(ufo.distance<=305.0)]
ufo1
# Out:
#        Unnamed: 0          datetime                          city state  \
# 12             13  10/10/1970 19:00                    manchester    ky
# 53             57  10/10/1993 23:00                      carthage    tn
# 77             81  10/10/1998 23:50                        delano    tn
# 663           683   10/1/2000 22:00                       jackson    tn
# 964           989  10/12/1973 19:00    birmingham (just south of)    al
# ...           ...               ...                           ...   ...
# 77893       79700    9/7/1999 12:15                      gallatin    tn
# 77906       79713    9/7/2000 21:20                        benton    ky
# 77921       79728    9/7/2002 20:30  mt. juliet  (near nashville)    tn
# 77931       79738    9/7/2002 23:15                  guntersville    al
# 78112       79922    9/8/2002 19:10                    germantown    tn
#
#       country     shape  duration           total_time  \
# ...

# %%
ufoa2004=ufo1[(ufo1.year<2004)]

ufoa2004
# Out:
#        Unnamed: 0          datetime                          city state  \
# 53             57  10/10/1993 23:00                      carthage    tn
# 77             81  10/10/1998 23:50                        delano    tn
# 663           683   10/1/2000 22:00                       jackson    tn
# 964           989  10/12/1973 19:00    birmingham (just south of)    al
# 1191         1224  10/13/1969 21:15                    millington    tn
# ...           ...               ...                           ...   ...
# 77893       79700    9/7/1999 12:15                      gallatin    tn
# 77906       79713    9/7/2000 21:20                        benton    ky
# 77921       79728    9/7/2002 20:30  mt. juliet  (near nashville)    tn
# 77931       79738    9/7/2002 23:15                  guntersville    al
# 78112       79922    9/8/2002 19:10                    germantown    tn
#
#       country      shape  duration           total_time  \
# ...

# %%
set1=set(ufoa2004.city.unique())

# %%
ufo_despues_2004=ufo[(ufo.year>2004)]
set2=set(ufo_despues_2004.city.unique())

# %%
set3=set1-set2

len(set3)
# Out:
# 137

# %%
list(set3)
# Out:
# ['owensboro',
#  'old hickory',
#  'nicholasville',
#  'hazel',
#  'pinson',
#  'southside (gadsden)',
#  'bowling green (plum springs)',
#  'marble hill',
#  'guntersville',
#  'elberfeld',
#  'culleoka',
#  'murfreesboro (just west of)',
#  'christiana',
#  'joelton (near;  i-24)',
#  'cullman',
#  'lenoir city',
#  'johnston city',
#  'pegram',
#  'fyffe',
#  'crossville',
#  'tupelo',
#  'chattanooga',
#  'kennett',
#  'quebeck',
#  'cookeville',
#  'ringgold',
#  'warrior',
#  'mercer county',
#  'lake city (sighting/50 miles north of)',
#  'dickson',
#  'okolona',
#  'russell springs',
#  'vanleer',
#  'lake center',
#  'hanson',
#  'leeds (outside birmingham)',
#  'signal mountain',
#  'rome (ga)/cedar bluff (al)',
#  'blytheville (s of; southbound i-55)',
#  'poseyville',
#  'tate',
#  'hopkinsville ((west of&#44 on i-24)',
#  'gallatin',
#  'bicknell',
#  'onton',
#  'mt. juliet  (near nashville)',
#  'louisville (directly over metropolitan area)',
#  'chapmansboro',
# ...

# %%
ufo_index=ufo.drop(['Unnamed: 0','date_posted','comments','year'], axis=1)
ufo_index=ufo.drop(['shape','state','duration','total_time'], axis=1)
ufo_index=ufo.drop(['shape','state','duration','total_time','Unnamed: 0','date_posted','comments','year'], axis=1)
ufo_index
# Out:
#                datetime        city country   latitude   longitude  \
# 0      10/10/1949 20:30  san marcos      us  29.883056  -97.941111
# 3      10/10/1956 21:00        edna      us  28.978333  -96.645833
# 4      10/10/1960 20:00     kaneohe      us  21.418056 -157.803611
# 5      10/10/1961 19:00     bristol      us  36.595000  -82.188889
# 7      10/10/1965 23:45     norwalk      us  41.117500  -73.408333
# ...                 ...         ...     ...        ...         ...
# 78504    9/9/2013 21:00   woodstock      us  34.101389  -84.519444
# 78505    9/9/2013 22:00       boise      us  43.613611 -116.202500
# 78506    9/9/2013 22:00        napa      us  38.297222 -122.284444
# 78507    9/9/2013 22:20      vienna      us  38.901111  -77.265556
# 78508    9/9/2013 23:00      edmond      us  35.652778  -97.477778
#
#           distance
# 0      1242.667772
# 3      1211.971352
# 4      6960.923396
# 5       427.334113
# 7      1295.827792
# ...            ...
# ...

# %%
ufo_index.reset_index(inplace=True)

# %%
ufo_index=ufo_index.drop(['level_0','index'], axis=1)
ufo_index
# Out:
#                datetime        city country   latitude   longitude  \
# 0      10/10/1949 20:30  san marcos      us  29.883056  -97.941111
# 1      10/10/1956 21:00        edna      us  28.978333  -96.645833
# 2      10/10/1960 20:00     kaneohe      us  21.418056 -157.803611
# 3      10/10/1961 19:00     bristol      us  36.595000  -82.188889
# 4      10/10/1965 23:45     norwalk      us  41.117500  -73.408333
# ...                 ...         ...     ...        ...         ...
# 63394    9/9/2013 21:00   woodstock      us  34.101389  -84.519444
# 63395    9/9/2013 22:00       boise      us  43.613611 -116.202500
# 63396    9/9/2013 22:00        napa      us  38.297222 -122.284444
# 63397    9/9/2013 22:20      vienna      us  38.901111  -77.265556
# 63398    9/9/2013 23:00      edmond      us  35.652778  -97.477778
#
#           distance
# 0      1242.667772
# 1      1211.971352
# 2      6960.923396
# 3       427.334113
# 4      1295.827792
# ...            ...
# ...

# %%
def geoquery(ufo_index):
    
    list_money_mean=[]
    sb_ratio=[]
    n_companies=[]
    
    for i in range(len(ufp_index)):
        
        q=list(
            db.geoloc.find(
                {'geo_loc': {'$near':{'$geometry':{
                    'type':'Point',
                    'coordinates':[ufo_index.longitude[i], ufo_index.latitude[i]]
                },
                                     '$maxDistance':310}}}
            )
        )
        
        l=len(q)
        
        money_mean=sum([q[j]['n_total_money'] for j in range(l)])/l
        
        list_money_mean.append(money_mean)
        
        big=sum([q[k]['company_class'].count('Big') if q[k]['company_class'].count('Big')!=0 else 1 for k in range(l)])
        start=sum([q[k]['company_class'].count('StartUp') for k in range(l)])
        
        sb_ratio.append(start/big)
        
        n_companies.append(l)
        
    df['around_companies']=n_companies

    df['money_density']=list_money_mean

    df['sb_ratio']=sb_ratio
        
    return df

# %%
for i in list(set3):
      if not i in ufo.city:
            ufo.city.drop(axis=0, inplace=True)

# %%
# Find the city
