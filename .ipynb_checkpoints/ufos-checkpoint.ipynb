# %% [markdown]
# # UFO Question
#
# Our data science team has predicted that the Earth is going to be invaded by an alien force in the
# next years. Our only hope is to replicate a device that can block all alien technology in a radius of
# ~300km. Sadly, the device was sold in 2004 to an anonymous buyer to protect her hometown and
# we don't know how contact her again. We know that the device has been active since 2004 in one
# city in the USA, and we want to know where to start our search.
# We've included a dataset called ​ufo.csv​. This dataset contains over 80,000 reports of UFO sightings
# over the last century (all of them verified by the ESA). Using this dataset, try to guess the city in
# which the device has been hidden.

# %%
from pymongo import MongoClient

import pandas as pd

import re

# %pip install folium
import folium
# Out:
# Requirement already satisfied: folium in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (0.12.1.post1)
# Requirement already satisfied: branca>=0.3.0 in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from folium) (0.4.2)
# Requirement already satisfied: numpy in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from folium) (1.20.3)
# Requirement already satisfied: jinja2>=2.9 in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from folium) (2.11.3)
# Requirement already satisfied: requests in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from folium) (2.26.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from requests->folium) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages (from requests->folium) (1.26.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
client=MongoClient("mongodb://localhost:27017")

db=client.ufo

client.list_database_names()

db=client.nueva_db

colec=db.n_coleccion

db.list_collection_names()

db=client.ufo

colec=db.ufo

# %%
df=pd.DataFrame(list(colec.find({}
                
               )))


df.head(2)
# Out:
#                         _id             datetime          city state country  \
# 0  624f109eef3c3090c22653c8  0  10/10/1949 20:30    san marcos    tx      us
# 1  624f109eef3c3090c22653c9  1  10/10/1949 21:00  lackland afb    tx     NaN
#
#       shape duration  total_time  \
# 0  cylinder   2700.0  45 minutes
# 1     light   7200.0     1-2 hrs
#
#                                             comments date_posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
#
#      longitude  year       distance
# 0  -97.9411111  2004  1242.66777234
# 1   -98.581082  2005  1325.48631876

# %%
df["datetime"] = df["datetime"].str.extract(r'(\d{4})')
df
# Out:
#                             _id        datetime                  city state  \
# 0      624f109eef3c3090c22653c8      0     1949            san marcos    tx
# 1      624f109eef3c3090c22653c9      1     1949          lackland afb    tx
# 2      624f109eef3c3090c22653ca      2     1955  chester (uk/england)   NaN
# 3      624f109eef3c3090c22653cb      3     1956                  edna    tx
# 4      624f109eef3c3090c22653cc      4     1960               kaneohe    hi
# ...                         ...    ...      ...                   ...   ...
# 78504  624f10a3ef3c3090c2278670  80326     2013             woodstock    ga
# 78505  624f10a3ef3c3090c2278671  80328     2013                 boise    id
# 78506  624f10a3ef3c3090c2278672  80329     2013                  napa    ca
# 78507  624f10a3ef3c3090c2278673  80330     2013                vienna    va
# 78508  624f10a3ef3c3090c2278674  80331     2013                edmond    ok
#
#       country     shape duration  total_time  \
# 0          us  cylinder   2700.0  45 minutes
# 1         NaN     light   7200.0     1-2 hrs
# 2          gb    circle     20.0  20 seconds
# 3          us    circle     20.0    1/2 hour
# 4          us     light    900.0  15 minutes
# ...       ...       ...      ...         ...
# 78504      us    sphere     20.0  20 seconds
# 78505      us    circle   1200.0  20 minutes
# 78506      us     other   1200.0        hour
# 78507      us    circle      5.0   5 seconds
# 78508      us     cigar   1020.0  17 minutes
#
#                                                 comments date_posted  \
# 0      This event took place in early fall around 194...   4/27/2004
# 1      1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005
# 2      Green/Orange circular disc over Chester&#44 En...   1/21/2008
# 3      My older brother and twin sister were leaving ...   1/17/2004
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004
# ...                                                  ...         ...
# 78504  Driving 575 at 21:00 hrs saw a white and green...   9/30/2013
# 78505  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...   9/30/2013
# 78506                                       Napa UFO&#44   9/30/2013
# 78507  Saw a five gold lit cicular craft moving fastl...   9/30/2013
# 78508  2 witnesses 2  miles apart&#44 Red &amp; White...   9/30/2013
#
#          latitude     longitude  year       distance
# 0      29.8830556   -97.9411111  2004  1242.66777234
# 1        29.38421    -98.581082  2005  1325.48631876
# 2            53.2     -2.916667  2008  6515.41657656
# 3      28.9783333   -96.6458333  2004   1211.9713516
# 4      21.4180556  -157.8036111  2004  6960.92339627
# ...           ...           ...   ...            ...
# 78504  34.1013889   -84.5194444  2013  318.719194807
# 78505  43.6136111     -116.2025  2013  2620.02153892
# 78506  38.2972222  -122.2844444  2013  3126.99141729
# 78507  38.9011111   -77.2655556  2013  904.740389278
# 78508  35.6527778   -97.4777778  2013  953.748461981
#
# [78509 rows x 15 columns]

# %%
df['count']=1
df.head()
# Out:
#                         _id    datetime                  city state country  \
# 0  624f109eef3c3090c22653c8  0     1949            san marcos    tx      us
# 1  624f109eef3c3090c22653c9  1     1949          lackland afb    tx     NaN
# 2  624f109eef3c3090c22653ca  2     1955  chester (uk/england)   NaN      gb
# 3  624f109eef3c3090c22653cb  3     1956                  edna    tx      us
# 4  624f109eef3c3090c22653cc  4     1960               kaneohe    hi      us
#
#       shape duration  total_time  \
# 0  cylinder   2700.0  45 minutes
# 1     light   7200.0     1-2 hrs
# 2    circle     20.0  20 seconds
# 3    circle     20.0    1/2 hour
# 4     light    900.0  15 minutes
#
#                                             comments date_posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# 2  Green/Orange circular disc over Chester&#44 En...   1/21/2008        53.2
# 3  My older brother and twin sister were leaving ...   1/17/2004  28.9783333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004  21.4180556
#
#       longitude  year       distance  count
# 0   -97.9411111  2004  1242.66777234      1
# 1    -98.581082  2005  1325.48631876      1
# 2     -2.916667  2008  6515.41657656      1
# 3   -96.6458333  2004   1211.9713516      1
# 4  -157.8036111  2004  6960.92339627      1

# %%
df["before"] = df.apply(lambda x: "OK" if int(x["datetime"]) < 2004 else "after", axis=1)
df.head(5)
# Out:
# /var/folders/y9/1ck368zx5tq778d5611f3syw0000gn/T/ipykernel_31808/2314048601.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["before"] = df.apply(lambda x: "OK" if int(x["datetime"]) < 2004 else "after", axis=1)
#                         _id    datetime        city state country     shape  \
# 0  624f109eef3c3090c22653c8  0     1949  san marcos    tx      us  cylinder
# 3  624f109eef3c3090c22653cb  3     1956        edna    tx      us    circle
# 4  624f109eef3c3090c22653cc  4     1960     kaneohe    hi      us     light
# 5  624f109eef3c3090c22653cd  5     1961     bristol    tn      us    sphere
# 7  624f109eef3c3090c22653cf  7     1965     norwalk    ct      us      disk
#
#   duration  total_time                                           comments  \
# 0   2700.0  45 minutes  This event took place in early fall around 194...
# 3     20.0    1/2 hour  My older brother and twin sister were leaving ...
# 4    900.0  15 minutes  AS a Marine 1st Lt. flying an FJ4B fighter/att...
# 5    300.0   5 minutes  My father is now 89 my brother 52 the girl wit...
# 7   1200.0  20 minutes  A bright orange color changing to reddish colo...
#
#   date_posted    latitude     longitude  year       distance  count before
# 0   4/27/2004  29.8830556   -97.9411111  2004  1242.66777234      1     OK
# 3   1/17/2004  28.9783333   -96.6458333  2004   1211.9713516      1     OK
# 4   1/22/2004  21.4180556  -157.8036111  2004  6960.92339627      1     OK
# 5   4/27/2007      36.595   -82.1888889  2007  427.334112543      1     OK
# 7   10/2/1999     41.1175   -73.4083333  1999   1295.8277925      1     OK

# %%
df = df[(df.country == "us")]
df.head()
# Out:
#                         _id    datetime        city state country     shape  \
# 0  624f109eef3c3090c22653c8  0     1949  san marcos    tx      us  cylinder
# 3  624f109eef3c3090c22653cb  3     1956        edna    tx      us    circle
# 4  624f109eef3c3090c22653cc  4     1960     kaneohe    hi      us     light
# 5  624f109eef3c3090c22653cd  5     1961     bristol    tn      us    sphere
# 7  624f109eef3c3090c22653cf  7     1965     norwalk    ct      us      disk
#
#   duration  total_time                                           comments  \
# 0   2700.0  45 minutes  This event took place in early fall around 194...
# 3     20.0    1/2 hour  My older brother and twin sister were leaving ...
# 4    900.0  15 minutes  AS a Marine 1st Lt. flying an FJ4B fighter/att...
# 5    300.0   5 minutes  My father is now 89 my brother 52 the girl wit...
# 7   1200.0  20 minutes  A bright orange color changing to reddish colo...
#
#   date_posted    latitude     longitude  year       distance  count before
# 0   4/27/2004  29.8830556   -97.9411111  2004  1242.66777234      1     OK
# 3   1/17/2004  28.9783333   -96.6458333  2004   1211.9713516      1     OK
# 4   1/22/2004  21.4180556  -157.8036111  2004  6960.92339627      1     OK
# 5   4/27/2007      36.595   -82.1888889  2007  427.334112543      1     OK
# 7   10/2/1999     41.1175   -73.4083333  1999   1295.8277925      1     OK
